# %%
import pandas as pd

# %% [markdown]
# DataFrame is a main object in pandas used to represent dat in tabular form (rows and columns)
# Mostly we work with heterogeneous data - heterogeneous data as a combination of a mixture of features, some are numerical, and some are categorical etc

# %%
# create Dataframe with dictionary
sample_dict  = {'Name': ['Dharun','Kamalesh','Deepak','Deva'],
                'Age': [21,22,22,24],
                'DOB':['2001-06-13','2001-06-20','2001-03-13','2001-02-13'],
                'Country':['India','India','Brazil','Australia']}
df = pd.DataFrame(sample_dict)
df
# Out:
#        Name  Age         DOB    Country
# 0    Dharun   21  2001-06-13      India
# 1  Kamalesh   22  2001-06-20      India
# 2    Deepak   22  2001-03-13     Brazil
# 3      Deva   24  2001-02-13  Australia

# %%
df.head(2)  # return first 2 rows
df.tail(2) # return last 2 rows
# Out:
#      Name  Age         DOB
# 2  Deepak   23  2001-03-13
# 3    Deva   24  2001-02-13

# %%
df.columns # property returns column index of the Dataframe
df.index   # property returns row index
df.dtypes # property returns datatypes
df.values # Return a Numpy representation of the DataFrame.
df.axes  # Return a list represent the row index and column index
df.size # total records count
df.shape # returns tuple represent the dimension of data
df.memory_usage() # returns memory occupied by each column in bytes
df.empty  #return bools df empty or not
# Out:
# False

# %%
# INDEXING
# iloc Index Based Selection
df.iloc[0] #retrieve first row
df.iloc[:,0] #retrieve first column
df.iloc[:2,0] # retrive first 2 values of furst colmn like slicing in python
df.iloc[[0,2],0] # passing list of row index of firsat column to fetch
df.iloc[-5:]  # returve last 5 rows
 
#loc Label Based Selection  Data INdex not its position
df.loc[:,'Name'] # retriev data from Name column
df.loc[:2,['Name','DOB']] # retriev data from Name and DOB column upto index 2

df.set_index('Age') # we can set any column as index using set_index method 

cols = ['country', 'province', 'region_1', 'region_2']
indices = [0, 1, 10, 100]
df = reviews.loc[indices, cols]

# %% [markdown]
# Note - iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10..

# %%
#conditional Selection
df['Name'] =='Dharun' # return Bool value for all columns
df.loc[df['Age']==22] # return columns with age 22
df.loc[(df['Age']>=22) & (df['Name'] =='Kamalesh')]
#isin is lets you select data whose value "is in" a list of values. For example, here's how we can use it to select wines only from Italy or France:
df.loc[df['Country'].isin(['India'])]
df['Country']= 'India' # Assign value to all the rows of the given column
df['Emp id'] = range(18000,18004) #create column and set values
df

# %% [markdown]
# Centred Transformation is one of  the common preprocessing steps before varioous machine learning algorithms
# Centred Transformation is nothing but subtracting mean from every row of the respective column

# %%
# Centred TRansformation
df['Age'].map(lambda x:x-df['Age'].mean())
# Out:
# 0   -1.25
# 1   -0.25
# 2   -0.25
# 3    1.75
# Name: Age, dtype: float64

# %%
df.groupby('Age').Age.sum()
# Out:
# Age
# 21    21
# 22    44
# 24    24
# Name: Age, dtype: int64

# %% [markdown]
# NaN always afloat Value
# Filling NUll value with the first non null value of the column  - Backfill strategy

# %%
#rename
reindexed = df.rename_axis(index='wines') # rename index
renamed = df.rename(columns={'region_1':'region','region_2':'locale'}) #rename columns

# %%
###    REad  csv file

housing_data = pd.read_csv('/Users/dharan-19096/Documents/datasets/housing.csv')
housing_data.head()
# Out:
#    0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0   0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1   0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2   0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3   0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4   0.02985   0.00   2.180  0  0.4580  6.4300  58...

# %% [markdown]
# https://storage.googleapis.com/kaggle-media/learn/images/LPWH19I.png

# %%
import pandas as pd
filePath = "/Users/dharan-19096/Documents/CRM_FAQ/datalog_1.csv"
csv_schema = {
    'uuid': 'string',
    'dataObject': 'string',
    'timestamp': 'int64',
}
df= pd.read_csv(filePath,header = None, quotechar = "\"", encoding = "UTF-8",dtype=csv_schema)
df.head()
# Out:
#                0                          1            2               3   \
# 0  delete_objects  {\"root\":{\"operator\":8  \"on\":null  \"value\":null
#
#                                4                                  5   \
# 0  \"operands\":[{\"operator\":12  \"on\":{\"class\":\"FinalClass_\"
#
#                       6                7                              8   \
# 0  \"property\":\"text\"  \"child\":null}  \"value\":{\"value\":[\"crm\"
#
#           9   ...                  20                  21               22  \
# 0  \"cliq\"]  ...  \"type\":\"text\"}  \"operands\":null}  {\"operator\":1
#
#                                   23                     24               25  \
# 0  \"on\":{\"class\":\"FinalClass_\"  \"property\":\"text\"  \"child\":null}
#
#                               26                  27                       28  \
# 0  \"value\":{\"value\":\"cliq\"  \"type\":\"text\"}  \"operands\":null}]}]}}
#
#               29
# 0  1722352898111
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Adjusting the data to have consistent lengths across all columns
data = {
    "Record Count": ["20K"] * 25 + ["20K (Single Shard)"] * 12,
    "Result Count": [100, 10, 655, 338, 1000, 430, 230, 1000, 10, 100, 10, 100, 400, 171, 77, 516, 70, 1000, 18, 350, 846, 213, 1, 10, 255,
                     10, 1, 100, 6, 48, 35, 15, 100, 48, 56, 145],
    "Avg Time (ms)": [30, 12, 532, 48, 110, 54, 32, 145, 12, 30, 9, 27, 48, 33, 19, 58, 20, 92, 33, 100, 170, 33, 7, 8.5, 38,
                      10, 4, 28, 6, 20, 15, 7, 26, 18, 20, 30],
    "Max Time (ms)": [44, 14, 1000, 48, 128, 54, 33, 1000, 14, 35, 13, 50, 55, 40, 21, 64, 23, 105, 53, 415, 180, 35, 8, 9, 42,
                      12, 5, 33, 7, 28, 20, 12, 31, 19, 21, 44],
    "Word Count": [None, None, 1000, None, 100, None, None, 1000, 1000, 1000, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 10, 10, 10, 10,
                   10, 10, 10, 10, 10, 10, 10, 100, 100, 100, 100]
}
# Find the minimum length of lists in the dictionary
min_length = min(len(lst) for lst in data.values())

# Trim each list in the dictionary to the minimum length
data = {key: value[:min_length] for key, value in data.items()}

# Create the DataFrame with consistent lengths
df = pd.DataFrame(data)
df_cleaned =df.dropna()

fig, axs = plt.subplots(3, 1, figsize=(8, 6))

# Plot 1: Result Count vs Avg Time (ms)
axs[0].scatter(df_cleaned["Result Count"], df_cleaned["Avg Time (ms)"], c='blue', label="Avg Time (ms)", alpha=0.7)
axs[0].set_title("Result Count vs Avg Time Taken (ms)")
axs[0].set_xlabel("Result Count")
axs[0].set_ylabel("Avg Time Taken (ms)")
axs[0].grid(True)
axs[0].legend()

# Plot 2: Result Count vs Max Time (ms)
axs[1].scatter(df_cleaned["Result Count"], df_cleaned["Max Time (ms)"], c='red', label="Max Time (ms)", alpha=0.7)
axs[1].set_title("Result Count vs Max Time Taken (ms)")
axs[1].set_xlabel("Result Count")
axs[1].set_ylabel("Max Time Taken (ms)")
axs[1].grid(True)
axs[1].legend()

# Plot 3: Result Count vs Word Count with Avg Time as color
sc = axs.scatter(df_cleaned["Result Count"], df_cleaned["Word Count"], c=df_cleaned["Avg Time (ms)"], cmap='viridis', alpha=0.7)
axs.set_title("Result Count vs Word Count (Avg Time as Color)")
axs.set_xlabel("Result Count")
axs.set_ylabel("Word Count")
axs.grid(True)
cbar = plt.colorbar(sc, ax=axs)
cbar.set_label('Avg Time (ms)')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 42
#      39 axs[1].legend()
#      41 # Plot 3: Result Count vs Word Count with Avg Time as color
# ---> 42 sc = axs.scatter(df_cleaned["Result Count"], df_cleaned["Word Count"], c=df_cleaned["Avg Time (ms)"], cmap='viridis', alpha=0.7)
#      43 axs.set_title("Result Count vs Word Count (Avg Time as Color)")
#      44 axs.set_xlabel("Result Count")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'scatter'

# %%
# Create the DataFrame
data = {
    "Records Count": [
        "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", 
        "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K(Single shard)", "20K(Single shard)",
        "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)",
        "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)",
        "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)",
        "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)"
    ],
    "Result Count": [
        100, 10, 655, 338, 1000, 430, 230, 1000, 10, 100, 10, 100, 400, 171, 77, 516, 70, 1000, 18, 350, 846, 213, 
        1, 10, 255, 4, 10, 1, 100, 6, 48, 35, 15, 100, 48, 56, 145, 1000, 10, 100, 1000, 443, 563, 310, 200, 500, 
        100, 200, 500, 1000, 10, 100, 200, 500, 1000
    ],
    "Avg Time (ms)": [
        30, 12, None, 48, 110, 54, 32, None, 12, 30, 9, 27, 48, 33, 19, 58, 20, 92, 33, 100, 170, 33, 7, 8.5, 38, 6, 
        10, 4, 10, 6, 20, 15, 7, None, 26, 18, 20, 30, 123, 7, 21, 120, 57, 63, 43, 33, 62, 16, 33, 64, 110, 11, 24, 
        36, 60, 115
    ],
    "Max Time (ms)": [
        44, 14, 532, 48, 128, 54, 33, 145, 14, 35, 13, 50, 55, 40, 21, 64, 23, 105, 53, 415, 180, 35, 8, 9, 42, 8, 12, 
        5, 7, 7, 28, 20, 12, 12, 31, 19, 21, 44, 400, 11, 34, 202, 60, 73, 48, 44, 65, 23, 36, 100, 119, 12, 37, 44, 
        66, 155
    ],
    "Word Count": [
        None, None, 1000, None, 100, None, 33, 1000, 1000, 1000, 100, 100, 100, 100, 100, 100, 100, 100, 100, 10, 
        100, 100, 10, 10, 10, 1, 10, 10, 10, 10, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 200, 200, 200, 200, 
        200, 500, 500, 500, 1000, 1000, 1000, 1000, 1000
    ]
}

# %%
import pandas as pd
# Create the DataFrame
df = pd.DataFrame(data)

# Clean the data:
# 1. Drop rows with any missing values
df = df.dropna()

# 2. Standardize the "Records Count" column
df['Records Count'] = df['Records Count'].str.replace("(SIngle shard)", "(Single shard)", regex=False)

# Convert numeric columns to appropriate types
df["Result Count"] = df["Result Count"].astype(int)
df["Avg Time (ms)"] = df["Avg Time (ms)"].astype(float)
df["Max Time (ms)"] = df["Max Time (ms)"].astype(float)
df["Word Count"] = df["Word Count"].astype(int)
df_0_100 = df[(df["Avg Time (ms)"] >= 0) & (df["Avg Time (ms)"] <= 100)]
df_100_1000 = df[(df["Avg Time (ms)"] > 100) & (df["Avg Time (ms)"] <= 1000)]

# Display the cleaned DataFram
fig, axs = plt.subplots(3, 1, figsize=(12, 10))

# Plot 1: Result Count vs Avg Time (ms)
axs[0].scatter(df_cleaned["Result Count"], df_cleaned["Avg Time (ms)"], c='blue', label="Avg Time (ms)", alpha=0.7)
axs[0].set_title("Result Count vs Avg Time Taken (ms)")
axs[0].set_xlabel("Result Count")
axs[0].set_ylabel("Avg Time Taken (ms)")
axs[0].grid(True)
axs[0].legend()

# Plot 2: Result Count vs Max Time (ms)
axs[1].scatter(df_cleaned["Result Count"], df_cleaned["Max Time (ms)"], c='red', label="Max Time (ms)", alpha=0.7)
axs[1].set_title("Result Count vs Max Time Taken (ms)")
axs[1].set_xlabel("Result Count")
axs[1].set_ylabel("Max Time Taken (ms)")
axs[1].grid(True)
axs[1].legend()

#plot 3: Result Count vs Word Count (Avg Time as Color)
sc = axs[2].scatter(df_cleaned["Result Count"], df_cleaned["Word Count"], c=df_cleaned["Avg Time (ms)"], cmap='viridis', alpha=0.7)
axs[2].set_title("Result Count vs Word Count (Avg Time as Color)")
axs[2].set_xlabel("Result Count")
axs[2].set_ylabel("Word Count")
axs[2].grid(True)
cbar = plt.colorbar(sc, ax=axs[2])
cbar.set_label('Avg Time (ms)')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 3
#       1 import pandas as pd
#       2 # Create the DataFrame
# ----> 3 df = pd.DataFrame(data)
#       5 # Clean the data:
#       6 # 1. Drop rows with any missing values
#       7 df = df.dropna()
#
# File ~/anaconda3/envs/weav/lib/python3.9/site-packages/pandas/core/frame.py:736, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     730     mgr = self._init_mgr(
#     731         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     732     )
#     734 elif isinstance(data, dict):
#     735     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 736     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     737 elif isinstance(data, ma.MaskedArray):
#     738     from numpy.ma import mrecords
#
# ...

# %%
# Filter the DataFrame for the two ranges
df_0_100 = df[(df["Avg Time (ms)"] >= 0) & (df["Avg Time (ms)"] <= 100)]
df_100_1000 = df[(df["Avg Time (ms)"] > 100) & (df["Avg Time (ms)"] <= 1000)]

# Plot 1: 0-100 ms
fig, axs = plt.subplots(2, 1, figsize=(12, 12))

# First plot for 0-100 ms
axs[0].scatter(df_0_100["Result Count"], df_0_100["Avg Time (ms)"], c='blue', label="Avg Time (ms)", alpha=0.7)
axs[0].set_title("Comparison for Avg Time Taken 0-100 ms")
axs[0].set_xlabel("Result Count")
axs[0].set_ylabel("Values")
axs[0].legend()
axs[0].grid(True)

# Plot 2: 100-1000 ms
axs[1].plot(df_100_1000["Result Count"], df_100_1000["Avg Time (ms)"], label="Avg Time Taken (ms)", marker='o', color='blue')
axs[1].plot(df_100_1000["Result Count"], df_100_1000["Max Time (ms)"], label="Max Time Taken (ms)", marker='s', color='red')
axs[1].plot(df_100_1000["Result Count"], df_100_1000["Word Count"], label="Word Count", marker='^', color='green')
axs[1].set_title("Comparison for Avg Time Taken 100-1000 ms")
axs[1].set_xlabel("Result Count")
axs[1].set_ylabel("Values")
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
df_0_100
# Out:
# Empty DataFrame
# Columns: [Records Count, Result Count, Avg Time (ms), Max Time (ms), Word Count]
# Index: []

# %%
import pandas as pd

# Dictionary with data
data_dict = {
    "Records Count": [
        "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", 
        "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K", "20K(Single shard)", "20K(Single shard)",
        "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)",
        "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)",
        "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)",
        "20K(Single shard)", "20K(Single shard)", "20K(Single shard)", "20K(Single shard)"
    ],
    "Result Count": [
        100, 10, 655, 338, 1000, 430, 230, 1000, 10, 100, 10, 100, 400, 171, 77, 516, 70, 1000, 18, 350, 846, 213, 
        1, 10, 255, 4, 10, 1, 100, 6, 48, 35, 15, 100, 48, 56, 145, 1000, 10, 100, 1000, 443, 563, 310, 200, 500, 
        100, 200, 500, 1000, 10, 100, 200, 500, 1000
    ],
    "Avg Time (ms)": [
        30, 12, None, 48, 110, 54, 32, None, 12, 30, 9, 27, 48, 33, 19, 58, 20, 92, 33, 100, 170, 33, 7, 8.5, 38, 6, 
        10, 4, 10, 6, 20, 15, 7, None, 26, 18, 20, 30, 123, 7, 21, 120, 57, 63, 43, 33, 62, 16, 33, 64, 110, 11, 24, 
        36, 60, 115
    ],
    "Max Time (ms)": [
        44, 14, 532, 48, 128, 54, 33, 145, 14, 35, 13, 50, 55, 40, 21, 64, 23, 105, 53, 415, 180, 35, 8, 9, 42, 8, 12, 
        5, 7, 7, 28, 20, 12, 12, 31, 19, 21, 44, 400, 11, 34, 202, 60, 73, 48, 44, 65, 23, 36, 100, 119, 12, 37, 44, 
        66, 155
    ],
    "Word Count": [
        None, None, 10000, None, 100, None, 33, 1000, 1000, 1000, 100, 100, 100, 100, 100, 100, 100, 100, 100, 10, 
        100, 100, 10, 10, 10, 1, 10, 10, 10, 10, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 200, 200, 200, 200, 
        200, 500, 500, 500, 1000, 1000, 1000, 1000, 1000
    ]
}

# Adjust lengths of lists to the same size by trimming or padding with None
max_length = max(len(v) for v in data_dict.values())
for key, value in data_dict.items():
    while len(value) < max_length:
        value.append(None)  # Add None for missing data
    while len(value) > max_length:
        value.pop()  # Remove extra data

# Convert dictionary to pandas DataFrame
df = pd.DataFrame(data_dict)

# Display the DataFrame
print(df)
# Out:
#         Records Count  Result Count  Avg Time (ms)  Max Time (ms)  Word Count
# 0                 20K         100.0           30.0             44         NaN
# 1                 20K          10.0           12.0             14         NaN
# 2                 20K         655.0            NaN            532     10000.0
# 3                 20K         338.0           48.0             48         NaN
# 4                 20K        1000.0          110.0            128       100.0
# 5                 20K         430.0           54.0             54         NaN
# 6                 20K         230.0           32.0             33        33.0
# 7                 20K        1000.0            NaN            145      1000.0
# 8                 20K          10.0           12.0             14      1000.0
# 9                 20K         100.0           30.0             35      1000.0
# 10                20K          10.0            9.0             13       100.0
# ...

# %%
# Filter the DataFrame for the two ranges
df_0_100 = df[(df["Avg Time (ms)"] >= 0) & (df["Avg Time (ms)"] <= 100)]
df_100_1000 = df[(df["Avg Time (ms)"] > 100) & (df["Avg Time (ms)"] <= 1000)]

# Plot 1: 0-100 ms
fig, axs = plt.subplots(2, 1, figsize=(12, 12))

# First plot for 0-100 ms
axs[0].scatter(df_0_100["Result Count"], df_0_100["Avg Time (ms)"], c='blue', label="Avg Time (ms)", alpha=0.7)
axs[0].set_title("Comparison for Avg Time Taken vs Results count")
axs[0].set_xlabel("Result Count")
axs[0].set_ylabel("Average Time")
axs[0].legend()
axs[0].grid(True)

# Plot 2: 100-1000 ms
axs[1].scatter(df_0_100["Word Count"], df_0_100["Avg Time (ms)"], c='blue', label="Avg Time (ms)", alpha=0.7)
axs[1].set_title("Comparison for Avg Time Taken vs word count")
axs[1].set_xlabel("Word Count")
axs[1].set_ylabel("Average Time")
axs[1].legend()
axs[1].grid(True)


plt.tight_layout()
plt.show()

# %%
# Plot 3: Result Count vs Word Count with Avg Time as color
fig, axs = plt.subplots(1, 1, figsize=(12, 8))

sc = axs.scatter(df_0_100["Result Count"], df_0_100["Word Count"], c=df_0_100["Avg Time (ms)"], cmap='viridis', alpha=0.7)
axs.set_title("Result Count vs Word Count (Avg Time as Color)")
axs.set_xlabel("Result Count")
axs.set_ylabel("Word Count")
axs.grid(True)
cbar = plt.colorbar(sc, ax=axs)
cbar.set_label('Avg Time (ms)')
plt.tight_layout()
plt.show()
